# %%
import pandas as pd
import re

# Load the Excel file into a DataFrame
file_path = 'C:/Users/User/Desktop/Ironhack_DA/Project-2/My_Data.csv'

# Read the Excel file
df1 = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df1.rename(columns={'Job titiles': 'Job_Title'}, inplace=True)
df1
# Out:
#                    Job_Title AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0     Communications Manager       98%    365       2546           0.143362
# 1             Data Collector       95%    299       2148           0.139199
# 2                 Data Entry       95%    325       2278           0.142669
# 3                 Mail Clerk       95%    193       1366           0.141288
# 4         Compliance Officer       92%    194       1369           0.141709
# ...                      ...       ...    ...        ...                ...
# 4701                  Singer        5%    686       2798           0.245175
# 4702                 Airport        5%    556       2206           0.252040
# 4703                Director        5%   1316       4695           0.280298
# 4704                   Nurse        5%    710       2594           0.273709
# 4705              Technician        5%    825       3256           0.253378
#
#                          Domain
# 0            Communication & PR
# 1                     Data & IT
# 2     Administrative & Clerical
# 3         Leadership & Strategy
# 4          Medical & Healthcare
# ...                         ...
# 4701                  Data & IT
# 4702  Administrative & Clerical
# 4703      Leadership & Strategy
# 4704       Medical & Healthcare
# 4705   Supply Chain & Logistics
#
# [4706 rows x 6 columns]

# %%
file_path2 = r'C:\Users\User\Desktop\Ironhack_DA\Project-2\AI Job Market Insights export 2025-03-15 14-27-22.csv'

# Read the Excel file
df2 = pd.read_csv(file_path2)
df2.sort_values(by='Job_Title', ascending=True)
# Out:
#          Job_Title            Industry Company_Size   Location  \
# 317  AI Researcher              Energy        Small  Singapore
# 85   AI Researcher           Education        Large   New York
# 84   AI Researcher       Manufacturing        Small     Berlin
# 301  AI Researcher      Transportation       Medium      Paris
# 82   AI Researcher          Technology        Large     Berlin
# ..             ...                 ...          ...        ...
# 464    UX Designer          Technology       Medium  Singapore
# 465    UX Designer              Retail        Small     London
# 432    UX Designer           Education       Medium     Sydney
# 116    UX Designer  Telecommunications        Small     Berlin
# 466    UX Designer           Education        Large      Tokyo
#
#     AI_Adoption_Level Automation_Risk Required_Skills     Salary_USD  \
# 317            Medium            High      JavaScript  101945.497751
# 85                Low            High           Sales   93594.369062
# 84               High          Medium          Python  115238.677535
# 301               Low            High          Python  110298.379649
# 82             Medium            High    UX/UI Design   97115.859499
# ..                ...             ...             ...            ...
# 464            Medium             Low   Data Analysis   82655.420193
# 465               Low          Medium   Data Analysis   53276.510711
# 432               Low          Medium   Data Analysis  109578.480137
# 116               Low             Low          Python   93313.178871
# 466               Low            High      JavaScript  121894.680146
#
#     Remote_Friendly Job_Growth_Projection
# 317              No                Stable
# 85               No                Growth
# 84               No               Decline
# 301             Yes               Decline
# 82               No                Growth
# ..              ...                   ...
# 464             Yes                Stable
# 465             Yes                Stable
# 432             Yes                Growth
# 116              No               Decline
# 466              No                Growth
#
# [500 rows x 10 columns]

# %%
file_path3 = r'C:\Users\User\Desktop\Ironhack_DA\Project-2\AI Job Market Insights export 2025-03-15 14-27-22.csv'

# Read the Excel file
df3 = pd.read_csv(file_path3)
df3
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0              Medium            High        UX/UI Design  111392.165243
# 1              Medium            High           Marketing   93792.562466
# 2              Medium            High        UX/UI Design  107170.263069
# 3                 Low            High  Project Management   93027.953758
# 4                 Low             Low          JavaScript   87752.922171
# ..                ...             ...                 ...            ...
# 495               Low          Medium    Machine Learning  105821.394046
# 496               Low            High        UX/UI Design  119794.992146
# 497              High             Low        UX/UI Design   79644.933099
# 498              High             Low              Python   77642.150625
# 499            Medium            High  Project Management   68764.378921
#
#     Remote_Friendly Job_Growth_Projection
# 0               Yes                Growth
# 1                No               Decline
# 2               Yes                Growth
# 3                No                Growth
# 4               Yes               Decline
# ..              ...                   ...
# 495             Yes                Stable
# 496              No               Decline
# 497             Yes                Stable
# 498             Yes                Stable
# 499             Yes               Decline
#
# [500 rows x 10 columns]

# %%
df2.Job_Title.unique()
# Out:
# array(['Cybersecurity Analyst', 'Marketing Specialist', 'AI Researcher',
#        'Sales Manager', 'UX Designer', 'HR Manager', 'Product Manager',
#        'Software Engineer', 'Data Scientist', 'Operations Manager'],
#       dtype=object)

# %%
df3.Job_Title.unique()
# Out:
# array(['Cybersecurity Analyst', 'Marketing Specialist', 'AI Researcher',
#        'Sales Manager', 'UX Designer', 'HR Manager', 'Product Manager',
#        'Software Engineer', 'Data Scientist', 'Operations Manager'],
#       dtype=object)

# %%
sorted(df1['Job_Title'].unique().tolist())
# Out:
# ['.Net Developer',
#  '3D Animator',
#  '3D Artist',
#  '3D Designer',
#  '3D Modeler',
#  '911 Dispatcher',
#  '911 Operator',
#  'Aba Therapist',
#  'Abap Developer',
#  'Academic Administrator',
#  'Academic Advisor',
#  'Academic Counselor',
#  'Academic Dean',
#  'Academic Director',
#  'Academic Tutor',
#  'Accessioner',
#  'Accompanist',
#  'Account Administrator',
#  'Account Analyst',
#  'Account Assistant',
#  'Account Coordinator',
#  'Account Executive',
#  'Account Representative',
#  'Accountant',
#  'Accounting Administrator',
#  'Accounting Analyst',
#  'Accounting Assistant',
#  'Accounting Associate',
#  'Accounting Auditor',
#  'Accounting Clerk',
#  'Accounting Consultant',
#  'Accounting Director',
#  'Accounting Instructor',
#  'Accounting Professor',
#  'Accounting Specialist',
#  'Accounting Technician',
#  'Accounting Tutor',
#  'Accounts Payable',
#  'Accounts Payable Analyst',
#  'Accounts Payable Assistant',
#  'Accounts Payable Clerk',
#  'Accounts Payable Coordinator',
#  'Accounts Payable Specialist',
#  'Accounts Receivable Clerk',
#  'Accounts Receivable Specialist',
#  'Acquisition Specialist',
#  'Activist',
#  'Activities Coordinator',
#  'Activities Director',
#  'Activity Assistant',
#  'Actor',
#  'Actuarial Analyst',
#  'Actuary',
#  'Acupuncturist',
#  'Acute Care Nurse Practitioner',
#  'Addiction Counselor',
#  'Adjunct Instructor',
#  'Adjunct Nursing Faculty',
#  'Adjunct Professor',
#  'Adjunct Teacher',
#  'Adjuster',
#  'Admin',
#  'Administration',
#  'Administration Manager',
#  'Administrative Analyst',
#  'Administrative Assistant',
#  'Administrative Associate',
#  'Administrative Clerk',
#  'Administrative Coordinator',
#  'Administrative Director',
#  'Administrative Law Judge',
#  'Administrative Manager',
#  'Administrative Officer',
#  'Administrative Secretary',
#  'Administrative Services Manager',
#  'Administrative Specialist',
#  'Administrator',
#  'Admissions Advisor',
#  'Admissions Assistant',
#  'Admissions Coordinator',
#  'Admissions Counselor',
#  'Admissions Officer',
#  'Admissions Representative',
#  'Admitting Clerk',
#  'Advertising Account Executive',
#  'Advertising Assistant',
#  'Advertising Coordinator',
#  'Advertising Director',
#  'Advertising Manager',
#  'Advertising Sales',
#  'Advertising Sales Representative',
#  'Advocate',
#  'Aerial Lineman',
#  'Aeronautical Engineer',
#  'Aerospace Engineer',
#  'Aerospace Technician',
#  'Aesthetic Nurse',
#  'Aesthetician',
#  'Affiliate Manager',
#  'After School Teacher',
#  'Agency Nurse',
#  'Agent',
#  'Agile Coach',
#  'Agile Project Manager',
#  'Agricultural Engineer',
#  'Agriculture Teacher',
#  'Agronomist',
#  'Aide',
#  'Air Marshal',
#  'Air Traffic Controller',
#  'Aircraft Assembler',
#  'Aircraft Cleaner',
#  'Aircraft Dispatcher',
#  'Aircraft Electrician',
#  'Aircraft Engineer',
#  'Aircraft Fueler',
#  'Aircraft Inspector',
#  'Aircraft Maintenance Technician',
#  'Aircraft Mechanic',
#  'Aircraft Painter',
#  'Aircraft Technician',
#  'Airline Pilot',
#  'Airport',
#  'Airport Attendant',
#  'Allocation Analyst',
#  'Ambassador',
#  'Aml Analyst',
#  'Analog Design Engineer',
#  'Analyst',
#  'Analytical Chemist',
#  'Analytical Scientist',
#  'Analytics Consultant',
#  'Analytics Manager',
#  'Anchor',
#  'Android Developer',
#  'Anesthesiologist',
#  'Anesthesiologist Assistant',
#  'Animal Care Technician',
#  'Animal Caretaker',
#  'Animal Control Officer',
#  'Animal Keeper',
#  'Animal Technician',
#  'Animal Trainer',
#  'Animator',
#  'Announcer',
#  'Antenna Engineer',
#  'Apartment Leasing Agent',
#  'Apartment Property Manager',
#  'Apparel Designer',
#  'Application Developer',
#  'Applications Engineer',
#  'Appointment Scheduler',
#  'Appointment Setter',
#  'Appraiser',
#  'Aquatics Director',
#  'Arabic Linguist',
#  'Arborist',
#  'Archaeologist',
#  'Architect',
#  'Architectural Drafter',
#  'Architectural Draftsman',
#  'Architectural Engineer',
#  'Architectural Project Manager',
#  'Archivist',
#  'Area Supervisor',
#  'Armed Guard',
#  'Armed Security',
#  'Armed Security Officer',
#  'Armored Truck Driver',
#  'Armorer',
#  'Art Director',
#  'Art Handler',
#  'Art Model',
#  'Art Professor',
#  'Art Therapist',
#  'Artist',
#  'Artistic Director',
#  'Arts Manager',
#  'Asic Design Engineer',
#  'Asp.Net Developer',
#  'Assembly Line Worker',
#  'Assembly Operator',
#  'Assembly Technician',
#  'Assembly Worker',
#  'Assessor',
#  'Asset Management Analyst',
#  'Asset Manager',
#  'Asset Protection Manager',
#  'Assignment Editor',
#  'Assistant',
#  'Assistant Account Executive',
#  'Assistant Administrator',
#  'Assistant Art Director',
#  'Assistant Athletic Director',
#  'Assistant Basketball Coach',
#  'Assistant Bookkeeper',
#  'Assistant Branch Manager',
#  'Assistant Brand Manager',
#  'Assistant Buyer',
#  'Assistant Coach',
#  'Assistant Community Manager',
#  'Assistant Construction Manager',
#  'Assistant Controller',
#  'Assistant Cook',
#  'Assistant Dean',
#  'Assistant Designer',
#  'Assistant Director',
#  'Assistant Director Of Nursing',
#  'Assistant District Attorney',
#  'Assistant Engineer',
#  'Assistant Facility Manager',
#  'Assistant Football Coach',
#  'Assistant Front Office Manager',
#  'Assistant General Manager',
#  'Assistant Golf Professional',
#  'Assistant Hotel Manager',
#  'Assistant Librarian',
#  'Assistant Manager',
#  'Assistant Marketing Manager',
#  'Assistant Media Planner',
#  'Assistant Nurse Manager',
#  'Assistant Operations Manager',
#  'Assistant Portfolio Manager',
#  'Assistant Principal',
#  'Assistant Producer',
#  'Assistant Product Manager',
#  'Assistant Professor',
#  'Assistant Project Manager',
#  'Assistant Property Manager',
#  'Assistant Registrar',
#  'Assistant Restaurant Manager',
#  'Assistant Sales Manager',
#  'Assistant Soccer Coach',
#  'Assistant Store Manager',
#  'Assistant Superintendent',
#  'Assistant Teacher',
#  'Assisted Living Administrator',
#  'Associate',
#  'Associate Attorney',
#  'Associate Brand Manager',
#  'Associate Buyer',
#  'Associate Consultant',
#  'Associate Creative Director',
#  'Associate Dean',
#  'Associate Dentist',
#  'Associate Editor',
#  'Associate Marketing Manager',
#  'Associate Pastor',
#  'Associate Product Manager',
#  'Associate Professor',
#  'Associate Project Manager',
#  'Associate Scientist',
#  'Associate Software Engineer',
#  'Associate Veterinarian',
#  'Athletic Coordinator',
#  'Athletic Director',
#  'Atm Technician',
#  'Attorney',
#  'Attorney General',
#  'Au Pair',
#  'Audio Engineer',
#  'Audio Technician',
#  'Audio Visual Technician',
#  'Audiologist',
#  'Audit Associate',
#  'Audit Director',
#  'Auditor',
#  'Author',
#  'Auto Appraiser',
#  'Auto Body Painter',
#  'Auto Body Technician',
#  'Auto Damage Appraiser',
#  'Auto Detailer',
#  'Auto Glass Technician',
#  'Auto Mechanic',
#  'Auto Sales',
#  'Auto Technician',
#  'Autocad Designer',
#  'Autocad Drafter',
#  'Autocad Draftsman',
#  'Automation Engineer',
#  'Automation Specialist',
#  'Automation Technician',
#  'Automation Test Engineer',
#  'Automation Tester',
#  'Automotive Consultant',
#  'Automotive Detailer',
#  'Automotive Engineer',
#  'Automotive Instructor',
#  'Automotive Mechanic',
#  'Automotive Sales Manager',
#  'Automotive Service Advisor',
#  'Automotive Service Manager',
#  'Automotive Service Technician',
#  'Automotive Technician',
#  'Autopsy Assistant',
#  'Aviation Maintenance Technician',
#  'Aviation Mechanic',
#  'Aviation Technician',
#  'Avionics Engineer',
#  'Avionics Technician',
#  'Babysitter',
#  'Backend Developer',
#  'Background Investigator',
#  'Baggage Handler',
#  'Bailiff',
#  'Baker',
#  'Bakery Assistant',
#  'Bakery Clerk',
#  'Bakery Manager',
#  'Band Director',
#  'Bank Examiner',
#  'Bank Teller',
#  'Banker',
#  'Banking Analyst',
#  'Banking Consultant',
#  'Bankruptcy Paralegal',
#  'Bankruptcy Specialist',
#  'Banquet Captain',
#  'Banquet Chef',
#  'Banquet Manager',
#  'Bar Manager',
#  'Bar Server',
#  'Barback',
#  'Barber',
#  'Barista',
#  'Bartender',
#  'Baseball Coach',
#  'Basketball Coach',
#  'Basketball Referee',
#  'Beach Attendant',
#  'Beautician',
#  'Beauty Advisor',
#  'Beauty Consultant',
#  'Behavior Analyst',
#  'Behavior Interventionist',
#  'Behavior Technician',
#  'Behavioral Technician',
#  'Behavioral Therapist',
#  'Bellhop',
#  'Bellman',
#  'Bench Jeweler',
#  'Bench Technician',
#  'Benefits Administrator',
#  'Benefits Analyst',
#  'Benefits Consultant',
#  'Benefits Manager',
#  'Benefits Specialist',
#  'Beverage Manager',
#  'Beverage Server',
#  'Bi Analyst',
#  'Bi Developer',
#  'Bid Manager',
#  'Bike Mechanic',
#  'Bilingual',
#  'Bilingual Customer Service',
#  'Bilingual Teacher',
#  'Billing Analyst',
#  'Billing Assistant',
#  'Billing Clerk',
#  'Billing Coordinator',
#  'Billing Manager',
#  'Billing Representative',
#  'Billing Specialist',
#  'Billing Supervisor',
#  'Bindery Operator',
#  'Biochemist',
#  'Bioinformatician',
#  'Bioinformatics',
#  'Biological Scientist',
#  'Biological Technician',
#  'Biology Instructor',
#  'Biology Tutor',
#  'Biomedical Engineer',
#  'Biomedical Equipment Technician',
#  'Biomedical Technician',
#  'Biostatistician',
#  'Biotechnology',
#  'Bishop',
#  'Biztalk Developer',
#  'Blackjack Dealer',
#  'Blog Writer',
#  'Blogger',
#  'Board Operator',
#  'Boat Captain',
#  'Body Shop Manager',
#  'Bodyguard',
#  'Boiler Operator',
#  'Boilermaker',
#  'Book Reviewer',
#  'Booking Agent',
#  'Bookkeeper',
#  'Bookkeeping',
#  'Bookseller',
#  'Bookstore',
#  'Bookstore Manager',
#  'Border Patrol Agent',
#  'Bouncer',
#  'Box Office Manager',
#  'Box Truck Driver',
#  'Branch Manager',
#  'Branch Office Administrator',
#  'Brand Ambassador',
#  'Brand Consultant',
#  'Brand Director',
#  'Brand Manager',
#  'Brand Marketing Manager',
#  'Brand Representative',
#  'Brand Specialist',
#  'Brand Strategist',
#  'Breakfast Attendant',
#  'Brewer',
#  'Brick Mason',
#  'Bricklayer',
#  'Bridal Consultant',
#  'Bridge Engineer',
#  'Bridge Inspector',
#  'Broadband Technician',
#  'Broadcast Engineer',
#  'Broadcast Journalist',
#  'Broadcast Producer',
#  'Broadcast Technician',
#  'Broker',
#  'Broker Assistant',
#  'Budget Analyst',
#  'Budget Manager',
#  'Budget Officer',
#  'Budtender',
#  'Build Engineer',
#  'Builder',
#  'Building Engineer',
#  'Building Inspector',
#  'Building Maintenance',
#  'Building Manager',
#  'Building Official',
#  'Building Superintendent',
#  'Bursar',
#  'Bus Aide',
#  'Bus Driver',
#  'Bus Monitor',
#  'Bus Operator',
#  'Busboy',
#  'Business Administrator',
#  'Business Advisor',
#  'Business Analyst',
#  'Business Analyst Manager',
#  'Business Architect',
#  'Business Assistant',
#  'Business Associate',
#  'Business Banker',
#  'Business Banking Relationship Manager',
#  'Business Consultant',
#  'Business Continuity Manager',
#  'Business Controller',
#  'Business Coordinator',
#  'Business Data Analyst',
#  'Business Developer',
#  'Business Development Analyst',
#  'Business Development Associate',
#  'Business Development Consultant',
#  'Business Development Coordinator',
#  'Business Development Director',
#  'Business Development Executive',
#  'Business Development Manager',
#  'Business Development Officer',
#  'Business Development Representative',
#  'Business Development Specialist',
#  'Business Director',
#  'Business Education Teacher',
#  'Business Instructor',
#  'Business Intelligence Analyst',
#  'Business Intelligence Consultant',
#  'Business Intelligence Developer',
#  'Business Intelligence Manager',
#  'Business Leader',
#  'Business Management Consultant',
#  'Business Manager',
#  'Business Objects Developer',
#  'Business Office Manager',
#  'Business Operations Manager',
#  'Business Operations Specialist',
#  'Business Partner',
#  'Business Process Analyst',
#  'Business Process Manager',
#  'Business Project Manager',
#  'Business Relationship Manager',
#  'Business Specialist',
#  'Business Strategist',
#  'Business Support',
#  'Business Systems Analyst',
#  'Business Teacher',
#  'Business Unit Manager',
#  'Busser',
#  'Butcher',
#  'Butler',
#  'Buyer',
#  'Buyer Planner',
#  'C Developer',
#  'C# Developer',
#  'CNA',
#  'CPA',
#  'CPR Instructor',
#  'CTO',
#  'Cabin Cleaner',
#  'Cabinet Installer',
#  'Cabinet Maker',
#  'Cable Installation Technician',
#  'Cable Technician',
#  'Cad Designer',
#  'Cad Drafter',
#  'Cad Engineer',
#  'Cad Operator',
#  'Cad Technician',
#  'Cafe Manager',
#  'Calibration Technician',
#  'Call Center',
#  'Call Center Agent',
#  'Call Center Director',
#  'Call Center Manager',
#  'Call Center Operator',
#  'Call Center Representative',
#  'Call Center Specialist',
#  'Call Center Supervisor',
#  'Caller',
#  'Camera Operator',
#  'Camp Counselor',
#  'Camp Director',
#  'Campaign Coordinator',
#  'Campaign Manager',
#  'Campground Manager',
#  'Campus Recruiter',
#  'Cancer Registrar',
#  'Cannabis',
#  'Canvasser',
#  'Captain',
#  'Car Dealer',
#  'Car Detailer',
#  'Car Driver',
#  'Car Mechanic',
#  'Car Porter',
#  'Car Sales',
#  'Cardiac Sonographer',
#  'Cardiologist',
#  'Cardiology Nurse Practitioner',
#  'Cardiothoracic Surgeon',
#  'Cardiovascular Technologist',
#  'Care Assistant',
#  'Care Manager',
#  'Care Provider',
#  'Care Taker',
#  'Career Advisor',
#  'Career Coach',
#  'Career Consultant',
#  'Career Counselor',
#  'Career Specialist',
#  'Caregiver',
#  'Caretaker',
#  'Cargo Agent',
#  'Cargo Handler',
#  'Carpenter',
#  'Carpenter Helper',
#  'Carpentry',
#  'Carpet Cleaner',
#  'Carrier',
#  'Cart Attendant',
#  'Cartographer',
#  'Case Aide',
#  'Case Manager',
#  'Case Worker',
#  'Cash Manager',
#  'Cashier',
#  'Casino',
#  'Casino Dealer',
#  'Casino Host',
#  'Casino Manager',
#  'Category Manager',
#  'Caterer',
#  'Catering Assistant',
#  'Catering Chef',
#  'Catering Coordinator',
#  'Catering Manager',
#  'Catering Sales Manager',
#  'Cdl Driver',
#  'Center Manager',
#  'Central Office Technician',
#  'Central Service Technician',
#  'Certified Athletic Trainer',
#  'Certified Dental Assistant',
#  'Certified Diabetes Educator',
#  'Certified Dietary Manager',
#  'Certified Home Health Aide',
#  'Certified Medical Assistant',
#  'Certified Medication Aide',
#  'Certified Nurse Aide',
#  'Certified Nurse Assistant',
#  'Certified Nurse Midwife',
#  'Certified Nursing Assistant',
#  'Certified Occupational Therapy Assistant',
#  'Certified Ophthalmic Assistant',
#  'Certified Personal Trainer',
#  'Certified Pharmacy Technician',
#  'Certified Phlebotomy Technician',
#  'Certified Professional Coder',
#  'Certified Public Accountant',
#  'Certified Surgical Technologist',
#  'Certified Welding Inspector',
#  'Cfd Engineer',
#  'Chairman',
#  'Change Management Consultant',
#  'Change Manager',
#  'Channel Manager',
#  'Channel Marketing Manager',
#  'Channel Sales Manager',
#  'Chaplain',
#  'Character Artist',
#  'Charge Nurse',
#  'Charter Pilot',
#  'Chartered Accountant',
#  'Chauffeur',
#  'Cheerleading Coach',
#  'Chef',
#  'Chef Assistant',
#  'Chef De Cuisine',
#  'Chef De Partie',
#  'Chef Manager',
#  'Chemical Dependency Counselor',
#  'Chemical Engineer',
#  'Chemical Lab Technician',
#  'Chemical Operator',
#  'Chemical Process Engineer',
#  'Chemical Technician',
#  'Chemist',
#  'Chemistry Professor',
#  'Chemistry Teacher',
#  'Chemistry Tutor',
#  'Chief Administrative Officer',
#  'Chief Communications Officer',
#  'Chief Compliance Officer',
#  'Chief Development Officer',
#  'Chief Diversity Officer',
#  'Chief Engineer',
#  'Chief Estimator',
#  'Chief Executive Officer (CEO)',
#  'Chief Financial Officer (CFO)',
#  'Chief Human Resources Officer',
#  'Chief Information Officer',
#  'Chief Information Security Officer',
#  'Chief Investment Officer',
#  'Chief Learning Officer',
#  'Chief Marketing Officer',
#  'Chief Medical Officer',
#  'Chief Nursing Officer',
#  'Chief Of Police',
#  'Chief Of Staff',
#  'Chief Risk Officer',
#  'Chief Security Officer',
#  'Chief Strategy Officer',
#  'Chief Technology Officer',
#  'Child Advocate',
#  'Child Care Assistant',
#  'Child Care Worker',
#  'Child Life Specialist',
#  'Child Psychiatrist',
#  'Child Psychologist',
#  'Childcare Teacher',
#  'Chinese Teacher',
#  'Chiropractic Assistant',
#  'Chiropractor',
#  'Choir Director',
#  'Choreographer',
#  'Church Musician',
#  'Cinematographer',
#  'Circuit Design Engineer',
#  'Circulation Manager',
#  'Cisco Engineer',
#  'Cisco Network Engineer',
#  'Cisco Voice Engineer',
#  'Citrix Administrator',
#  'Citrix Engineer',
#  'City Attorney',
#  'City Clerk',
#  'City Driver',
#  'City Engineer',
#  'City Manager',
#  'City Planner',
#  'Civil Designer',
#  'Civil Drafter',
#  'Civil Engineer',
#  'Civil Engineering Technician',
#  'Civil Project Engineer',
#  'Civil Structural Engineer',
#  'Claim Adjuster',
#  'Claim Analyst',
#  'Claim Examiner',
#  'Claim Representative',
#  'Claim Specialist',
#  'Claims',
#  'Claims Adjuster',
#  'Claims Analyst',
#  'Claims Assistant',
#  'Claims Auditor',
#  'Claims Clerk',
#  'Claims Examiner',
#  'Claims Investigator',
#  'Claims Manager',
#  'Claims Processor',
#  'Claims Representative',
#  'Claims Supervisor',
#  'Class A CDL',
#  'Class A Driver',
#  'Class B CDL',
#  'Class B Driver',
#  'Classroom Aide',
#  'Classroom Assistant',
#  'Classroom Teacher',
#  'Cleaner',
#  'Clerical Assistant',
#  'Clerk',
#  'Clerk Typist',
#  'Client Advisor',
#  'Client Associate',
#  'Client Coordinator',
#  'Client Manager',
#  'Client Relations Manager',
#  'Client Relationship Manager',
#  'Client Service Associate',
#  'Client Services Manager',
#  'Client Success Manager',
#  'Clinic Assistant',
#  'Clinic Manager',
#  'Clinic Receptionist',
#  'Clinical Analyst',
#  'Clinical Assistant',
#  'Clinical Associate',
#  'Clinical Consultant',
#  'Clinical Coordinator',
#  'Clinical Data Analyst',
#  'Clinical Data Associate',
#  'Clinical Data Coordinator',
#  'Clinical Data Manager',
#  'Clinical Dietitian',
#  'Clinical Director',
#  'Clinical Documentation Specialist',
#  'Clinical Educator',
#  'Clinical Engineer',
#  'Clinical Exercise Physiologist',
#  'Clinical Informatics Specialist',
#  'Clinical Instructor',
#  'Clinical Laboratory Scientist',
#  'Clinical Laboratory Technician',
#  'Clinical Laboratory Technologist',
#  'Clinical Liaison',
#  'Clinical Manager',
#  'Clinical Medical Assistant',
#  'Clinical Nurse',
#  'Clinical Nurse Educator',
#  'Clinical Nurse Manager',
#  'Clinical Nurse Specialist',
#  'Clinical Nursing Instructor',
#  'Clinical Operations Manager',
#  'Clinical Pharmacist',
#  'Clinical Project Manager',
#  'Clinical Psychologist',
#  'Clinical Research',
#  'Clinical Research Assistant',
#  'Clinical Research Associate',
#  'Clinical Research Coordinator',
#  'Clinical Research Manager',
#  'Clinical Research Nurse',
#  'Clinical Scientist',
#  'Clinical Social Worker',
#  'Clinical Specialist',
#  'Clinical Supervisor',
#  'Clinical Support Specialist',
#  'Clinical Systems Analyst',
#  'Clinical Technician',
#  'Clinical Therapist',
#  'Clinical Trial Assistant',
#  'Clinical Trial Associate',
#  'Clinical Trial Manager',
#  'Clinician',
#  'Cloud Architect',
#  'Cloud Consultant',
#  'Cloud Engineer',
#  'Club Manager',
#  'Cmm Operator',
#  'Cmm Programmer',
#  'Cnc Machine Operator',
#  'Cnc Machinist',
#  'Cnc Operator',
#  'Cnc Programmer',
#  'Coach',
#  'Coating Inspector',
#  'Cobol Developer',
#  'Cocktail Server',
#  'Cocktail Waitress',
#  'Code Enforcement Officer',
#  'Coding Specialist',
#  'Coffee Roaster',
#  'Coffee Shop Manager',
#  'Cognos Developer',
#  'Coldfusion Developer',
#  'Collection Agent',
#  'Collection Analyst',
#  'Collection Manager',
#  'Collection Representative',
#  'Collection Specialist',
#  'Collection Supervisor',
#  'Collections Agent',
#  'Collections Specialist',
#  'College Advisor',
#  'College Counselor',
#  'College Instructor',
#  'Colorist',
#  'Combat Engineer',
#  'Combo Welder',
#  'Comic',
#  'Commercial Account Manager',
#  'Commercial Analyst',
#  'Commercial Banker',
#  'Commercial Diver',
#  'Commercial Driver',
#  'Commercial Lender',
#  'Commercial Loan Officer',
#  'Commercial Manager',
#  'Commercial Pilot',
#  'Commercial Project Manager',
#  'Commercial Property Manager',
#  'Commercial Real Estate Appraiser',
#  'Commercial Real Estate Broker',
#  'Commercial Sales Manager',
#  'Commercial Underwriter',
#  'Commission Analyst',
#  'Commissioning Engineer',
#  'Commodity Buyer',
#  'Commodity Trader',
#  'Communication Technician',
#  'Communications',
#  'Communications Associate',
#  'Communications Consultant',
#  'Communications Coordinator',
#  'Communications Manager',
#  'Communications Officer',
#  'Communications Specialist',
#  'Communications Technician',
#  'Communicator',
#  'Community Assistant',
#  'Community Association Manager',
#  'Community Health Educator',
#  'Community Health Nurse',
#  'Community Health Worker',
#  'Community Liaison',
#  'Community Manager',
#  'Community Organizer',
#  'Community Outreach Coordinator',
#  'Community Outreach Specialist',
#  'Community Planner',
#  'Community Service Officer',
#  'Community Worker',
#  'Companion',
#  'Company Driver',
#  'Compensation Manager',
#  'Compensation Specialist',
#  'Compliance Analyst',
#  'Compliance Auditor',
#  'Compliance Officer',
#  'Compliance Specialist',
#  'Component Engineer',
#  'Composite Technician',
#  'Compositor',
#  'Compounder',
#  'Computational Biologist',
#  'Computational Linguist',
#  'Computer Engineer',
#  'Computer Operator',
#  'Computer Programmer',
#  'Computer Repair Technician',
#  'Computer Science Teacher',
#  'Computer Science Tutor',
#  'Computer Scientist',
#  'Computer Support Specialist',
#  'Computer Systems Analyst',
#  'Computer Teacher',
#  'Computer Technician',
#  'Concept Artist',
#  'Concierge',
#  'Concrete Finisher',
#  'Concrete Pump Operator',
#  'Concrete Truck Driver',
#  'Concrete Worker',
#  'Conductor',
#  'Conference Coordinator',
#  'Configuration Analyst',
#  'Configuration Manager',
#  'Conservationist',
#  'Conservator',
#  'Console Operator',
#  'Constable',
#  'Construction Administrator',
#  'Construction Apprentice',
#  'Construction Assistant',
#  'Construction Consultant',
#  'Construction Coordinator',
#  'Construction Driver',
#  'Construction Engineer',
#  'Construction Estimator',
#  'Construction Flagger',
#  'Construction Foreman',
#  'Construction Helper',
#  'Construction Inspector',
#  'Construction Laborer',
#  'Construction Manager',
#  'Construction Project Coordinator',
#  'Construction Project Engineer',
#  'Construction Project Manager',
#  'Construction Superintendent',
#  'Construction Supervisor',
#  'Construction Technician',
#  'Construction Worker',
#  'Consultant',
#  'Consulting Engineer',
#  'Contact Center Manager',
#  'Contact Tracer',
#  'Contact Tracing',
#  'Content Creator',
#  'Content Developer',
#  'Content Editor',
#  'Content Manager',
#  'Content Producer',
#  'Content Specialist',
#  'Content Strategist',
#  'Content Writer',
#  'Contract Administrator',
#  'Contract Analyst',
#  'Contract Attorney',
#  'Contract Driver',
#  'Contract Manager',
#  'Contract Negotiator',
#  'Contract Specialist',
#  'Contracts Manager',
#  'Control Engineer',
#  'Control Room Operator',
#  'Controller',
#  'Controls Engineer',
#  'Controls Technician',
#  'Cook',
#  'Coordinator',
#  'Cop',
#  'Copier Technician',
#  'Copy Editor',
#  'Copy Writer',
#  'Copywriter',
#  'Coroner',
#  'Corporate Accountant',
#  'Corporate Attorney',
#  'Corporate Controller',
#  'Corporate Counsel',
#  'Corporate Event Planner',
#  'Corporate Financial Analyst',
#  'Corporate Lawyer',
#  'Corporate Paralegal',
#  'Corporate Pilot',
#  'Corporate Receptionist',
#  'Corporate Recruiter',
#  'Corporate Trainer',
#  'Corporate Travel Consultant',
#  'Correction Officer',
#  'Correctional Officer',
#  'Corrosion Engineer',
#  'Corrosion Technician',
#  'Cosmetic Chemist',
#  'Cosmetologist',
#  'Cosmetology Instructor',
#  'Cosmetology Teacher',
#  'Cost Accountant',
#  'Cost Accounting Manager',
#  'Cost Analyst',
#  'Cost Controller',
#  'Cost Engineer',
#  'Cost Estimator',
#  'Costume Designer',
#  'Counseling Psychologist',
#  'Counselor',
#  'Counter Manager',
#  'Courier',
#  'Courier Driver',
#  'Court Administrator',
#  'Court Clerk',
#  'Court Interpreter',
#  'Court Officer',
#  'Court Reporter',
#  'Court Security Officer',
#  'Courtesy Clerk',
#  'Cowboy',
#  'Craftsman',
#  'Crane Operator',
#  'Creative Assistant',
#  'Creative Consultant',
#  'Creative Designer',
#  'Creative Director',
#  ...]

# %%
keywords = ['Data', 'Analyst', 'specialist', 'AI', 'UX', 'Product', 'ENGINEER', 'OPERATIONS']
keywords_lower = [re.escape(k.lower()) for k in keywords]

regex_pattern = '|'.join(keywords_lower)
#df1_filtered = df1[df1['Job_Title'].str.contains(regex_pattern, case=False, na=False)]

# %%
df1['Job_Title'].apply(lambda x: re.findall(regex_pattern, x.lower())[0] if re.findall(regex_pattern, x.lower()) else None)
# Out:
# 0       None
# 1       data
# 2       data
# 3         ai
# 4       None
#         ...
# 4701    None
# 4702      ai
# 4703    None
# 4704    None
# 4705    None
# Name: Job_Title, Length: 4706, dtype: object

# %%
df1['Job_Title_2'] = df1['Job_Title'].apply(lambda x: re.findall(regex_pattern, x.lower())[0] if re.findall(regex_pattern, x.lower()) else None)

df1
# Out:
#                    Job_Title AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0     Communications Manager       98%    365       2546           0.143362
# 1             Data Collector       95%    299       2148           0.139199
# 2                 Data Entry       95%    325       2278           0.142669
# 3                 Mail Clerk       95%    193       1366           0.141288
# 4         Compliance Officer       92%    194       1369           0.141709
# ...                      ...       ...    ...        ...                ...
# 4701                  Singer        5%    686       2798           0.245175
# 4702                 Airport        5%    556       2206           0.252040
# 4703                Director        5%   1316       4695           0.280298
# 4704                   Nurse        5%    710       2594           0.273709
# 4705              Technician        5%    825       3256           0.253378
#
#                          Domain Job_Title_2
# 0            Communication & PR        None
# 1                     Data & IT        data
# 2     Administrative & Clerical        data
# 3         Leadership & Strategy          ai
# 4          Medical & Healthcare        None
# ...                         ...         ...
# 4701                  Data & IT        None
# 4702  Administrative & Clerical          ai
# 4703      Leadership & Strategy        None
# 4704       Medical & Healthcare        None
# 4705   Supply Chain & Logistics        None
#
# [4706 rows x 7 columns]

# %%
df3.Job_Title.unique()
# Out:
# array(['Cybersecurity Analyst', 'Marketing Specialist', 'AI Researcher',
#        'Sales Manager', 'UX Designer', 'HR Manager', 'Product Manager',
#        'Software Engineer', 'Data Scientist', 'Operations Manager'],
#       dtype=object)

# %%
df1_cleaned = df1[df1['Job_Title_2'].notna()]

# %%
# columnns in df1_cleaned matching df3 & df2
'Cyber Security Analyst'
'Ux Designer'
'Product Manager',
'Software Engineer',
'Data Scientist',
'Operations Manager',
# Out:
# ('Operations Manager',)

# %%
replacements = {
    'Cyber Security Analyst': 'Cybersecurity Analyst',
    'Ux Designer': 'UX Designer',
    'Product Manager': 'Product Manager',
    'Software Engineer': 'Software Engineer',
    'Data Scientist': 'Data Scientist',
    'Operations Manager': 'Operations Manager'
}

# Assuming df1_cleaned is a view rather than a copy
df1_cleaned.loc[:, 'Job_Title'] = df1_cleaned['Job_Title'].replace(replacements)

# %%
# Use .loc to avoid SettingWithCopyWarning
df1_cleaned.loc[:, 'AI Impact'] = (df1_cleaned['AI Impact'].astype(str))

df1_cleaned.loc[:, 'AI Impact'] = df1_cleaned['AI Impact'].str.strip().str.rstrip('%').replace('nan', None)

# Handle possible missing values before conversion
df1_cleaned.loc[:, 'AI Impact'] = df1_cleaned['AI Impact'].astype(int)

# %%
df1_cleaned.to_csv('df1_cleaned.csv', index=False)

# %%
df1_cleaned.head()
# Out:
#          Job_Title AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 1   Data Collector        95    299       2148           0.139199
# 2       Data Entry        95    325       2278           0.142669
# 3       Mail Clerk        95    193       1366           0.141288
# 10    Mail Handler        90    188       1350           0.139259
# 11      Data Clerk        90    317       2258           0.140390
#
#                        Domain Job_Title_2
# 1                   Data & IT        data
# 2   Administrative & Clerical        data
# 3       Leadership & Strategy          ai
# 10         Communication & PR          ai
# 11                  Data & IT        data

# %%
df2.to_csv('df2.csv', index=False)

# %%
df3.to_csv('df3.csv',index=False)

# %%
df1_cleaned.columns.unique()
df2.columns.unique()
# Out:
# Index(['Job_Title', 'Industry', 'Company_Size', 'Location',
#        'AI_Adoption_Level', 'Automation_Risk', 'Required_Skills', 'Salary_USD',
#        'Remote_Friendly', 'Job_Growth_Projection'],
#       dtype='object')

# %%
df2.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Large  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.165243
# 1            Medium            High           Marketing   93792.562466
# 2            Medium            High        UX/UI Design  107170.263069
# 3               Low            High  Project Management   93027.953758
# 4               Low             Low          JavaScript   87752.922171
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# 2             Yes                Growth
# 3              No                Growth
# 4             Yes               Decline

# %%
df3.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Large  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.165243
# 1            Medium            High           Marketing   93792.562466
# 2            Medium            High        UX/UI Design  107170.263069
# 3               Low            High  Project Management   93027.953758
# 4               Low             Low          JavaScript   87752.922171
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# 2             Yes                Growth
# 3              No                Growth
# 4             Yes               Decline

# %%
df1_cleaned.head()
# Out:
#          Job_Title AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 1   Data Collector       95%    299       2148           0.139199
# 2       Data Entry       95%    325       2278           0.142669
# 3       Mail Clerk       95%    193       1366           0.141288
# 10    Mail Handler       90%    188       1350           0.139259
# 11      Data Clerk       90%    317       2258           0.140390
#
#                        Domain Job_Title_2
# 1                   Data & IT        data
# 2   Administrative & Clerical        data
# 3       Leadership & Strategy          ai
# 10         Communication & PR          ai
# 11                  Data & IT        data

# %%
# reuploading our joined data from workbench MySQL

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns

file_path = r'C:\Users\User\Desktop\Ironhack_DA\Project-2\df1_df2_joined_cleaned.csv'

df_final = pd.read_csv(file_path)
df_final = df_final.rename(columns={"AI Impact": "AI Impact %"})

# %%
df_final
# Out:
#                  Job_Title            Industry Company_Size       Location  \
# 0    Cybersecurity Analyst       Entertainment        Small          Dubai
# 1     Marketing Specialist          Technology        Large      Singapore
# 2    Cybersecurity Analyst       Entertainment        Small          Tokyo
# 3              UX Designer           Education        Large  San Francisco
# 4    Cybersecurity Analyst          Technology        Small          Dubai
# ..                     ...                 ...          ...            ...
# 338  Cybersecurity Analyst              Energy       Medium         Berlin
# 339         Data Scientist  Telecommunications       Medium         Berlin
# 340  Cybersecurity Analyst  Telecommunications        Small         London
# 341  Cybersecurity Analyst              Energy        Large          Dubai
# 342     Operations Manager          Healthcare        Large          Paris
#
#     AI_Adoption_Level Automation_Risk   Required_Skills  Salary_USD  \
# 0              Medium            High      UX/UI Design    111392.0
# 1              Medium            High         Marketing     93792.6
# 2                 Low             Low        JavaScript     87752.9
# 3              Medium          Medium     Cybersecurity    102825.0
# 4              Medium             Low  Machine Learning     86607.3
# ..                ...             ...               ...         ...
# 338            Medium            High      UX/UI Design     79936.9
# 339               Low          Medium  Machine Learning    105821.0
# 340               Low            High      UX/UI Design    119795.0
# 341              High             Low      UX/UI Design     79644.9
# 342              High             Low            Python     77642.1
#
#     Remote_Friendly Job_Growth_Projection  AI Impact %  Tasks  AI models  \
# 0               Yes                Growth           20      7         54
# 1                No               Decline           20    281       2181
# 2               Yes               Decline           20      7         54
# 3                No                Growth           50    129        993
# 4               Yes               Decline           20      7         54
# ..              ...                   ...          ...    ...        ...
# 338              No               Decline           20      7         54
# 339             Yes                Stable           70    180       1091
# 340              No               Decline           20      7         54
# 341             Yes                Stable           20      7         54
# 342             Yes                Stable           25    232       1461
#
#      AI_Workload_Ratio                 Domain
# 0             0.129630   Medical & Healthcare
# 1             0.128840  Leadership & Strategy
# 2             0.129630   Medical & Healthcare
# 3             0.129909     Communication & PR
# 4             0.129630   Medical & Healthcare
# ..                 ...                    ...
# 338           0.129630   Medical & Healthcare
# 339           0.164986              Data & IT
# 340           0.129630   Medical & Healthcare
# 341           0.129630   Medical & Healthcare
# 342           0.158795     Communication & PR
#
# [343 rows x 15 columns]

# %%
# 1st insight:
ai_impact_by_risk = grouped_df_final_1.groupby("Automation_Risk")["AI Impact"].mean()
ai_impact_by_risk
# Out:
# Automation_Risk
# High      46.666667
# Low       47.500000
# Medium    35.000000
# Name: AI Impact, dtype: float64

# %%
# 1st insight graph
# Plot the data
ax = ai_impact_by_risk.plot(kind='bar', color=['r', 'g', 'b'])

# Adding a title and labels for clarity
plt.title('Average AI Impact by Automation Risk')
plt.xlabel('Automation Risk')
plt.ylabel('Average AI Impact')

# Add the numbers on top of the bars
for index, value in enumerate(ai_impact_by_risk):
    plt.text(index, value + 0.5, round(value, 2), ha='center')

# Show the plot
plt.show()

# %%
# 2nd insight, let's exprove per job title

grouped_df_final_2 = df_final.groupby("Job_Title").agg({
    "AI_Adoption_Level": lambda x: x.mode()[0],
    "Automation_Risk": lambda x: x.mode()[0],
    "Job_Growth_Projection": lambda x: x.mode()[0],
    "AI Impact %": "mean"
})

grouped_df_final_1.to_csv('grouped_df_final_1.csv',index=False)
grouped_df_final_1
# we enter the table in the ppt and we add explations based on screenshot by Hilena, we can focus on some of the Job titles like Data Sc and Software engineer
# Out:
#                       AI_Adoption_Level Automation_Risk Job_Growth_Projection  \
# Job_Title
# Cybersecurity Analyst            Medium            High                Stable
# Data Scientist                      Low             Low               Decline
# Marketing Specialist             Medium          Medium               Decline
# Operations Manager               Medium             Low                Growth
# Product Manager                    High            High                Growth
# Software Engineer                   Low            High                Growth
# UX Designer                         Low          Medium               Decline
#
#                        AI Impact
# Job_Title
# Cybersecurity Analyst       20.0
# Data Scientist              70.0
# Marketing Specialist        20.0
# Operations Manager          25.0
# Product Manager             60.0
# Software Engineer           60.0
# UX Designer                 50.0

# %%
# 3rd insight lets go explore the required skills because the 2nd insight needs further exploration
grouped_df_final_2 = df_final.groupby("Required_Skills").agg({
    "AI_Adoption_Level": lambda x: x.mode()[0],
    "Automation_Risk": lambda x: x.mode()[0],
    "AI Impact %": "mean"
})

grouped_df_final_2

#consclusion about the skills: for example Python has low Automarion risk even though the adoption level is high
# Out:
#                    AI_Adoption_Level Automation_Risk  AI Impact %
# Required_Skills
# Communication                    Low             Low    38.200000
# Cybersecurity                 Medium          Medium    42.435897
# Data Analysis                 Medium             Low    47.413793
# JavaScript                       Low            High    41.964286
# Machine Learning              Medium            High    47.272727
# Marketing                       High          Medium    43.088235
# Project Management               Low            High    48.068182
# Python                          High             Low    42.500000
# Sales                         Medium            High    43.593750
# UX/UI Design                     Low             Low    41.081081

# %%
# 3rd insight visulatisation to use in ppt

fig, ax = plt.subplots(figsize=(12, 4))  # Adjust width and height to fit content
ax.axis('off')  # Turn off the axis

# Create the table from the DataFrame
mpl_table = ax.table(
    cellText=grouped_df_final_2.values,
    colLabels=grouped_df_final_2.columns,
    rowLabels=grouped_df_final_2.index,
    cellLoc='center',
    loc='center'
)

# Styling
mpl_table.auto_set_font_size(False)
mpl_table.set_fontsize(10)
mpl_table.scale(1.2, 1.2)

# Header color
for (i, j), cell in mpl_table.get_celld().items():
    if i == 0 or j == -1:
        cell.set_text_props(weight='bold', color='white')
        cell.set_facecolor('#40466e')  # Header background color
    elif i % 2 == 0:
        cell.set_facecolor('#f0f0f0')  # Alternate row color

# Title
plt.title('Skills Characteristics Overview', fontsize=12, weight='bold', color='#40466e')

plt.show()

# %%
df_final.head()
# Out:
#                Job_Title       Industry Company_Size       Location  \
# 0  Cybersecurity Analyst  Entertainment        Small          Dubai
# 1   Marketing Specialist     Technology        Large      Singapore
# 2  Cybersecurity Analyst  Entertainment        Small          Tokyo
# 3            UX Designer      Education        Large  San Francisco
# 4  Cybersecurity Analyst     Technology        Small          Dubai
#
#   AI_Adoption_Level Automation_Risk   Required_Skills  Salary_USD  \
# 0            Medium            High      UX/UI Design    111392.0
# 1            Medium            High         Marketing     93792.6
# 2               Low             Low        JavaScript     87752.9
# 3            Medium          Medium     Cybersecurity    102825.0
# 4            Medium             Low  Machine Learning     86607.3
#
#   Remote_Friendly Job_Growth_Projection  AI Impact %  Tasks  AI models  \
# 0             Yes                Growth           20      7         54
# 1              No               Decline           20    281       2181
# 2             Yes               Decline           20      7         54
# 3              No                Growth           50    129        993
# 4             Yes               Decline           20      7         54
#
#    AI_Workload_Ratio                 Domain
# 0           0.129630   Medical & Healthcare
# 1           0.128840  Leadership & Strategy
# 2           0.129630   Medical & Healthcare
# 3           0.129909     Communication & PR
# 4           0.129630   Medical & Healthcare

# %%
# 4th insight: average workload ratio per Job title

grouped_df_final_3 = df_final.groupby("Job_Title").agg({
    "AI_Workload_Ratio": "mean"})

grouped_df_final_3 = grouped_df_final_3.sort_values(by="AI_Workload_Ratio", ascending=False)
grouped_df_final_3

# On average, only 13.41% of tasks in IT-related jobs are currently managed by AI. This suggests AI is augmenting rather than replacing the majority of IT work — aligning with your hypothesis that the fear may be overstated.
# Out:
#                        AI_Workload_Ratio
# Job_Title
# Data Scientist                  0.164986
# Operations Manager              0.158795
# UX Designer                     0.129909
# Cybersecurity Analyst           0.129630
# Marketing Specialist            0.128840
# Product Manager                 0.112587
# Software Engineer               0.099106

# %%
average_ai_workload_ratio = df_final["AI_Workload_Ratio"].mean()
average_ai_workload_ratio
# Out:
# 0.13410903440233238

# %%
# 4th insight focusing on Data Scientist role: We see the highest ratio 16.50%; which around 3.5% above the avergae value accross all roles.
# And at the same time this role has low risk of automation.
# Surprising! Even with low AI use and low automation risk, this job is strongly impacted by AI. Possibly due to targeted task automation

# %%
# let's explore Software engineer
# from our results: Software Engineer	Low	High	Growth	60.0
# one conclusion: Despite low adoption, AI has high impact — likely automation of specific parts of the role. Growth shows new AI-driven job formats.
